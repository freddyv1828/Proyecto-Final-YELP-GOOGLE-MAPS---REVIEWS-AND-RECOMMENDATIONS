# %%
# @title Example 1: Query a table with SQL and magic commands
# Running this code will query a table in BigQuery and download
# the results to a Pandas DataFrame named `results`.
# Learn more here: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%bigquery results --project eminent-cycle-415715
SELECT * FROM `eminent-cycle-415715.prueba_ai_ML.checkin` #this table name was set based on the table you chose to query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# You can view the resulting Pandas DataFrame and work with using the Pandas library.
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
results
# Out:
#                  business_id  \
# 0     VGN37glLit5oxbHIZ837Ag
# 1     W7gSJz80DywKnPRIGjA2Bw
# 2     eTJ60uyATafMzOMUeHpV_Q
# 3     s-qqQbITwg1SYJYpvreAJA
# 4     GyC36Pn0Q1-qHnqXys6yFg
# ...                      ...
# 8786  huta5nl96oXBxnFIQeMTTA
# 8787  sV22U6poI2ru77UXDhH8kg
# 8788  51YfncbIi2gVOJEJUd_8qg
# 8789  BQUyn-NDrIHI1Ke7C6tV2Q
# 8790  c_MsK_ra1MB1Q9KvZgNwww
#
#                                                    date  count
# 0     ['2013-08-24 21:04:29', '2013-09-08 02:41:45',...    256
# 1     ['2010-06-02 01:16:40', '2010-08-22 20:19:33',...    256
# 2     ['2013-07-06 18:19:40', '2013-07-12 20:21:41',...    256
# 3     ['2012-03-07 00:27:51', '2012-05-28 18:23:58',...    256
# 4     ['2010-06-22 12:25:07', '2010-08-11 14:04:32',...    512
# ...                                                 ...    ...
# 8786  ['2010-11-23 23:45:17', '2010-12-02 16:59:02',...    766
# 8787  ['2010-05-16 05:08:28', '2010-06-19 18:02:23',...   1022
# 8788  ['2010-06-25 05:03:14', '2010-06-25 05:06:24',...    255
# 8789  ['2011-01-27 00:33:07', '2011-03-16 00:58:35',...    255
# 8790  ['2010-06-16 00:38:13', '2010-07-11 18:39:15',...    767
#
# [8791 rows x 3 columns]

# %%
# @title Example 2: Query a table with BigQuery DataFrames
# With BigQuery DataFrames, you can use many familiar Pandas methods, but the
# processing happens BigQuery rather than the runtime, allowing you to work with larger
# DataFrames that would otherwise not fit in the runtime memory.
# Learn more here: https://cloud.google.com/python/docs/reference/bigframes/latest

import bigframes.pandas as bf

bf.options.bigquery.location = "us-central1" #this variable is set based on the dataset you chose to query
bf.options.bigquery.project = "eminent-cycle-415715" #this variable is set based on the dataset you chose to query

# %%
df = bf.read_gbq("eminent-cycle-415715.prueba_ai_ML.checkin") #this variable is set based on the dataset you chose to query

# %%
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)
# Out:
# Query job 0e6a760f-b56e-4ddc-8c4e-4ad0f597c321 is DONE. 22.3 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:0e6a760f-b56e-4ddc-8c4e-4ad0f597c321&page=queryresults">Open Job</a>
# Query job a7686e4f-c5a5-499f-a4e5-a5226d09c0cc is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:a7686e4f-c5a5-499f-a4e5-a5226d09c0cc&page=queryresults">Open Job</a>
# Query job 91adf6b0-fa62-4044-8158-2ab6d197760c is DONE. 75.4 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:91adf6b0-fa62-4044-8158-2ab6d197760c&page=queryresults">Open Job</a>
#                business_id                                               date  \
# 0   -VHgGQzPP5UWg46cmqztYA  ['2010-11-15 19:25:22', '2011-01-23 18:09:27',...
# 1   qEGWsxf9t2YbHCv0n2M4qQ  ['2011-09-14 16:27:27', '2012-09-21 21:28:00',...
# 2   3SNNs-aAO1P6_LX7-lzr9g  ['2011-12-15 16:38:03', '2011-12-16 13:45:50',...
# 3   pTUbmjUB2yAG9S63vMzISg                            ['2013-01-07 20:38:11']
# 4   cAbdvzqtFLaAAMFIyPf2AA  ['2010-03-21 03:20:51', '2010-03-21 03:20:54',...
# 5   jBEpbsG4ZLfPaZ3pCr2jZQ  ['2011-03-16 22:48:14', '2011-04-05 19:36:36',...
# 6   9qSeYLlh-vOHk9XX7v1LHA  ['2019-04-25 15:19:49', '2019-06-24 14:57:48',...
# 7   QH4h7s7PsSM9wsDTqOoM7Q  ['2017-01-05 22:58:42', '2017-06-05 20:49:30',...
# 8   Vqc-ibXU4ilVer_L8YbWJg  ['2011-01-28 23:33:24', '2011-06-26 00:38:43',...
# 9   LRTU8SUyCXRhQrqRlJCr6A  ['2010-02-17 18:30:35', '2010-03-24 16:14:41',...
# 10  OXpYyvWPTb_l02GfswFdHQ  ['2011-01-20 00:55:46', '2011-06-07 14:57:07',...
# 11  -veGIq3SvwFMi5ZwMSIqkg  ['2014-05-11 02:57:18', '2015-03-26 03:16:14',...
# 12  o62XMPkOG8sjEvcKi5HFCw  ['2013-03-25 04:34:50', '2013-03-25 07:29:56',...
# 13  pV0xgMdZED5M3ukcH36aJA  ['2014-05-16 15:57:37', '2014-06-27 17:57:08',...
# 14  bK8QVY9eZ66ANC_Kzph6ng  ['2011-07-04 23:09:15', '2012-09-22 19:38:18',...
# 15  whUZtCYYcYvWu5Q37B76Pw     ['2014-07-15 17:06:14', '2014-07-16 11:17:29']
# 16  ent_M5k2xHY9FNskAobpow  ['2012-05-18 14:06:13', '2012-10-07 15:04:48',...
# 17  xX66v8dVyQ4JdGgPWEDufA  ['2014-01-22 18:26:29', '2014-01-27 15:24:10',...
# 18  IYzqGs1e28misAwcZvf8yg  ['2010-04-09 18:24:45', '2010-05-08 19:48:36',...
# 19  P7Nf3Wl4fAIJ9O67RT6Cyw  ['2012-10-18 00:40:21', '2012-10-22 19:51:13',...
#
#     count
# 0      58
# 1      22
# 2      55
# 3       1
# 4     971
# 5     163
# 6       3
# 7       3
# 8      61
# 9     136
# 10     43
# 11      5
# 12     38
# 13     19
# 14      5
# 15      2
# 16     47
# 17      9
# 18   1548
# 19     45
#
# [20 rows x 3 columns]

# %%
# Verificar la distribución de la variable count
total_checkins = df['count'].count()
max_checkins = df['count'].max()
min_checkins = df['count'].min()
avg_checkins = df['count'].mean()
std_dev_checkins = df['count'].std()

print("Total check-ins:", total_checkins)
print("Max check-ins:", max_checkins)
print("Min check-ins:", min_checkins)
print("Avg check-ins:", avg_checkins)
print("Std Dev check-ins:", std_dev_checkins)
# Out:
# Query job 04d8032a-d849-4011-ad26-375300dc1621 is DONE. 70.3 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:04d8032a-d849-4011-ad26-375300dc1621&page=queryresults">Open Job</a>
# Query job 04bf63fe-6874-4fc4-b7a4-f79da642295b is DONE. 70.3 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:04bf63fe-6874-4fc4-b7a4-f79da642295b&page=queryresults">Open Job</a>
# Query job cb9e5660-b31b-462a-8345-b5af76774fab is DONE. 70.3 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:cb9e5660-b31b-462a-8345-b5af76774fab&page=queryresults">Open Job</a>
# Query job 73b93033-2aea-4475-a71e-ef545c3ec38e is DONE. 70.3 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:73b93033-2aea-4475-a71e-ef545c3ec38e&page=queryresults">Open Job</a>
# Query job ea0f5034-0128-4d68-ba96-e13f527ee867 is DONE. 70.3 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:ea0f5034-0128-4d68-ba96-e13f527ee867&page=queryresults">Open Job</a>
# Total check-ins: 8791
# Max check-ins: 13420
# Min check-ins: 1
# Avg check-ins: 108.87487202821052
# Std Dev check-ins: 318.6072289924353

# %%
# Identificar los lugares con mayor actividad de check-in
top_places = df.groupby('business_id').count().reset_index().sort_values(by='count', ascending=False)
top_places = top_places.rename(columns={'count': 'total_checkins'})
print(top_places)
# Out:
# Query job d4d14cdf-5ded-4ff9-962d-6ec9e239471d is DONE. 22.4 MB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:d4d14cdf-5ded-4ff9-962d-6ec9e239471d&page=queryresults">Open Job</a>
# Query job 898e184b-df5a-480b-a8bb-84c5f2a812c5 is DONE. 0 Bytes processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:898e184b-df5a-480b-a8bb-84c5f2a812c5&page=queryresults">Open Job</a>
# Query job c8c50d78-46f6-42bf-9300-e17eb9311ffb is DONE. 562.6 kB processed. <a target="_blank" href="https://console.cloud.google.com/bigquery?project=eminent-cycle-415715&j=bq:us-central1:c8c50d78-46f6-42bf-9300-e17eb9311ffb&page=queryresults">Open Job</a>
#                business_id  date  total_checkins
# 0   ---kPU91CF4Lq2-WlRu9Lw     0               1
# 1   --LC8cIrALInl2vyo701tg     0               1
# 2   --pDYWb4DzqKdAdrPcxuaA     0               1
# 3   --rS-rnOIZxoiDA8yctWpQ     0               1
# 4   -0EdehHjIQc0DtYU8QcAig     0               1
# 5   -0H_3r6z2giieA6oSTUFKQ     0               1
# 6   -0oPt7sSKtJG1ysLwV_E9g     0               1
# 7   -16EH6b1ho0xQqP0Bzm9Mg     0               1
# 8   -1Bvqy9wtFDyUB8GuDqQQw     0               1
# 9   -1WM2044r3jVZC6oQ2QeVA     0               1
# 10  -1YvpVvnnLrTZ0zjtUYPXA     0               1
# 11  -1g8Qb6t_mSX_ak1thMmrQ     1               1
# 12  -1ueCbvIpUPi8KT95ETTKw     0               1
# 13  -3xX_IfttKjPJ792BOBJ-Q     0               1
# 14  -4HTX6yWNuRJusCTezaUnQ     0               1
# 15  -4gHyiiX6NKNqQ0DO8QhwQ     0               1
# 16  -5fXJjU1oeWnCHW5MPOuxg     0               1
# 17  -5psHqEISccHDdHaWF2-6Q     0               1
# 18  -6L_z3ftD1iepJb0FfJghw     0               1
# 19  -6RKk3sSh-PWB8VBfy4KnQ     0               1
# 20  -75oKRpwa1VEHOLXBFJ2Cw     0               1
# 21  -7KAng29RoHr87mvOFbK9w     0               1
# 22  -7UDKbg_8TL4LVuYR6Ooyw     0               1
# 23  -7q7v1jepdduhzJZjpB91A     0               1
# 24  -8iATYRnN46Km0_-ldx6cg     0               1
# ...
#
# [8791 rows x 3 columns]
