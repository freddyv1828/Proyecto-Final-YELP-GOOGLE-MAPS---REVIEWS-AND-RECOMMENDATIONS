# %%
import pandas as pd
import funciones
import numpy as np
from collections import Counter

# %% [markdown]
# ### Rutas de los archivos

# %%
ruta_cities = '../DATASETS/uscities.xlsx'

# %%
ruta = '../DATASETS/business.pkl'

# %% [markdown]
# ### Abrimos archivo business

# %%
df_business = pd.read_pickle(ruta)
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# ...

# %% [markdown]
# Obseravmos las columnas duplicadas

# %%
df_business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id', 'name', 'address',
#        'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# Eliminamos columns duplicadas

# %%
df_business = df_business.iloc[:, :14]
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
# ...

# %%
df_business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %% [markdown]
# ### Abrimos archivo cities

# %%
df_cities = pd.read_excel(ruta_cities)
df_cities.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4      Houston      Houston       TX       Texas        48201       Harris
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18908608  11080.3  shape     False          True
# 1  34.1141 -118.4068    11922389   3184.7  shape     False          True
# 2  41.8375  -87.6866     8497759   4614.5  shape     False          True
# 3  25.7840  -80.2101     6080145   4758.9  shape     False          True
# 4  29.7860  -95.3885     5970127   1384.0  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# ...

# %% [markdown]
# obtenemos columnas que nos interesan

# %%
df_cities = df_cities[["city_ascii", "state_id"]]

# %%
df_cities.head()
# Out:
#     city_ascii state_id
# 0     New York       NY
# 1  Los Angeles       CA
# 2      Chicago       IL
# 3        Miami       FL
# 4      Houston       TX

# %% [markdown]
# AGregar columnas id a ambos datasets

# %%
df_cities["id"] = df_cities.index
df_business["id"] = df_business.index

# %% [markdown]
# combinar datasets

# %%
df_combined = pd.merge(df_business, df_cities, how="inner", on="id")
df_combined.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
# 2  32.223236 -110.880452   3.5           22       0
# ...

# %% [markdown]
# Corregimos inconsistencias

# %%
# Detectar inconsistencias (por ejemplo, ciudad en df_business no coincide con ninguna ciudad en df_cities)
df_combined["city_match"] = df_combined["city"] == df_combined["city_ascii"]

# %%
# Corregir ciudades y estados usando el dataset "cities"
df_combined["city"] = df_combined["city_ascii"]
df_combined["state"] = df_combined["state_id"]

# %%
# Eliminar columnas redundantes
df_combined.drop(columns=["city_ascii", "state_id"], inplace=True)

# %%
df_combined.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'id', 'city_match'],
#       dtype='object')

# %%
df_business = df_combined

# %% [markdown]
# Extraemos latitud y longitud de cities

# %%
dfcities2 = pd.read_excel(ruta_cities)

# %%
coordenadas = dfcities2[["lat", "lng"]]

# %% [markdown]
# creamos un id a coordenadas

# %%
coordenadas["id"] = coordenadas.index
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4712\1006431995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coordenadas["id"] = coordenadas.index

# %% [markdown]
# combinamos con business

# %%
df_business = pd.merge(df_business, coordenadas, how="inner", on="id")

# %%
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address         city state postal_code   latitude  \
# 0           1616 Chapala St, Ste 2     New York    NY       93101  34.426679
# 1  87 Grasso Plaza Shopping Center  Los Angeles    CA       63123  38.551126
# 2             5255 E Broadway Blvd      Chicago    IL       85711  32.223236
# 3                      935 Race St        Miami    FL       19107  39.955505
# 4                    101 Walnut St      Houston    TX       18054  40.338183
#
#     longitude stars review_count is_open  \
# 0 -119.711197   5.0            7       0
# 1  -90.335695   3.0           15       1
# 2 -110.880452   3.5           22       0
# ...

# %% [markdown]
# Corregimos latitude y longitude

# %%
df_business["latitude"] = df_business["lat"]
df_business["longitude"] = df_business["lng"]

# %%
df_business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'id', 'city_match', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# Obtenemos columnas deseadas

# %%
df_business = df_business[["business_id", "name", "address", "city", "state", "latitude", "longitude", "stars", "review_count", "is_open", "attributes", "categories", "hours",]]

# %%
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address         city state  latitude  longitude  \
# 0           1616 Chapala St, Ste 2     New York    NY   40.6943   -73.9249
# 1  87 Grasso Plaza Shopping Center  Los Angeles    CA   34.1141  -118.4068
# 2             5255 E Broadway Blvd      Chicago    IL   41.8375   -87.6866
# 3                      935 Race St        Miami    FL   25.7840   -80.2101
# 4                    101 Walnut St      Houston    TX   29.7860   -95.3885
#
#   stars review_count is_open  \
# 0   5.0            7       0
# 1   3.0           15       1
# 2   3.5           22       0
# 3   4.0           80       1
# 4   4.5           13       1
#
# ...

# %%
df_business["hours"]=df_business["hours"].replace('{', '[', regex=True)
df_business["hours"]=df_business["hours"].replace('}', ']', regex=True)
df_business["attributes"]=df_business["attributes"].replace('"{', '[', regex=True)
df_business["attributes"]=df_business["attributes"].replace('}"', ']', regex=True)
df_business["attributes"]=df_business["attributes"].replace('{', '[', regex=True)
df_business["attributes"]=df_business["attributes"].replace('}', ']', regex=True)

# %%
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address         city state  latitude  longitude  \
# 0           1616 Chapala St, Ste 2     New York    NY   40.6943   -73.9249
# 1  87 Grasso Plaza Shopping Center  Los Angeles    CA   34.1141  -118.4068
# 2             5255 E Broadway Blvd      Chicago    IL   41.8375   -87.6866
# 3                      935 Race St        Miami    FL   25.7840   -80.2101
# 4                    101 Walnut St      Houston    TX   29.7860   -95.3885
#
#   stars review_count is_open  \
# 0   5.0            7       0
# 1   3.0           15       1
# 2   3.5           22       0
# 3   4.0           80       1
# 4   4.5           13       1
#
# ...

# %%
df_business = df_business.drop(['is_open'], axis=1)

# %%
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address         city state  latitude  longitude  \
# 0           1616 Chapala St, Ste 2     New York    NY   40.6943   -73.9249
# 1  87 Grasso Plaza Shopping Center  Los Angeles    CA   34.1141  -118.4068
# 2             5255 E Broadway Blvd      Chicago    IL   41.8375   -87.6866
# 3                      935 Race St        Miami    FL   25.7840   -80.2101
# 4                    101 Walnut St      Houston    TX   29.7860   -95.3885
#
#   stars review_count                                         attributes  \
# 0   5.0            7                      {'ByAppointmentOnly': 'True'}
# ...

# %%
state_origin = df_business["state"].unique()
state_origin
# Out:
# array(['NY', 'CA', 'IL', 'FL', 'TX', 'PA', 'GA', 'DC', 'MA', 'AZ', 'MI',
#        'WA', 'MN', 'CO', 'NV', 'MD', 'MO', 'OR', 'PR', 'IN', 'OH', 'VA',
#        'NC', 'WI', 'RI', 'TN', 'UT', 'OK', 'CT', 'KY', 'LA', 'NE', 'AL',
#        'NM', 'SC', 'IA', 'KS', 'AR', 'ID', 'NJ', 'HI', 'MS', 'AK', 'NH',
#        'ND', 'ME', 'SD', 'WV', 'MT', 'DE', 'VT', 'WY'], dtype=object)

# %%
desired_states = ['NV', 'FL', 'CA']
filtered_df = df_business[df_business['state'].isin(desired_states)]
filtered_df
# Out:
#                   business_id                      name  \
# 1      mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3      MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 13     jaxMSoInw8Poo3XeMJt8lQ              Adams Dental
# 14     0bPLkL0QhhPO5kt1_EXmNQ      Zio's Italian Market
# 16     rBmpy_Y1UbBx8ggHlyb7hA  Arizona Truck Outfitters
# ...                       ...                       ...
# 31094  gLPlHz4xHajEWqQ88w8_tg                      Wawa
# 31097  QtgubTRRFHtEL_fmsMQRCg                  Fujiyama
# 31104  FoInxau7UwTN2vguRTBNQA           Hong Restaurant
# 31113  -bgu0iDSGLlYZoeRs2qdoA                 Taco Bell
# 31114  J85Ien0NnLdWhtopkfWA2g                   Parkway
#
#                                address           city state  latitude  \
# 1      87 Grasso Plaza Shopping Center    Los Angeles    CA   34.1141
# 3                          935 Race St          Miami    FL   25.7840
# 13                   15 N Missouri Ave  San Francisco    CA   37.7558
# ...

# %%
state = filtered_df["state"].unique()
state
# Out:
# array(['CA', 'FL', 'NV'], dtype=object)

# %%
filtered_df.dropna(axis=0, how='any')
# Out:
#                   business_id                      name  \
# 1      mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 3      MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 13     jaxMSoInw8Poo3XeMJt8lQ              Adams Dental
# 14     0bPLkL0QhhPO5kt1_EXmNQ      Zio's Italian Market
# 16     rBmpy_Y1UbBx8ggHlyb7hA  Arizona Truck Outfitters
# ...                       ...                       ...
# 31094  gLPlHz4xHajEWqQ88w8_tg                      Wawa
# 31097  QtgubTRRFHtEL_fmsMQRCg                  Fujiyama
# 31104  FoInxau7UwTN2vguRTBNQA           Hong Restaurant
# 31113  -bgu0iDSGLlYZoeRs2qdoA                 Taco Bell
# 31114  J85Ien0NnLdWhtopkfWA2g                   Parkway
#
#                                address           city state  latitude  \
# 1      87 Grasso Plaza Shopping Center    Los Angeles    CA   34.1141
# 3                          935 Race St          Miami    FL   25.7840
# 13                   15 N Missouri Ave  San Francisco    CA   37.7558
# ...

# %%
funciones.verificar_datos(filtered_df)
# Out:
# Advertencia: la columna attributes, tiene valores nulos
# Advertencia: la columna categories, tiene valores nulos
# Advertencia: la columna hours, tiene valores nulos
#          columna                             tipo_dato  datos_nulos  \
# 0    business_id                       [<class 'str'>]            0
# 1           name                       [<class 'str'>]            0
# 2        address                       [<class 'str'>]            0
# 3           city                       [<class 'str'>]            0
# 4          state                       [<class 'str'>]            0
# 5       latitude                     [<class 'float'>]            0
# 6      longitude                     [<class 'float'>]            0
# 7          stars                     [<class 'float'>]            0
# 8   review_count                       [<class 'int'>]            0
# 9     attributes  [<class 'dict'>, <class 'NoneType'>]          218
# ...

# %%
# Assuming your DataFrame is named `df_business`

# Find rows with null values in "categories"
df_null_categories = filtered_df[filtered_df['categories'].isnull()]
df_null_categories
# Out:
#                   business_id                          name  \
# 1917   SMYXOLPyM95JvZ-oqnsWUA  A A Berlin Glass & Mirror Co
# 3324   _obl2-rphXvtzP3y_ekV1Q      Certegy Payment Services
# 13023  cs7i8-NtrT2P4dMYa2fX-g                    Direct USA
#
#                       address          city state  latitude  longitude stars  \
# 1917    60 W White Horse Pike      Rosemont    CA   38.5478  -121.3553   3.0
# 3324   11601 Roosevelt Blvd N  Florida City    FL   25.4418   -80.4685   1.0
# 13023   6201 Johns Rd, Ste 12        Midway    FL   28.7924   -81.2314   1.0
#
#       review_count attributes categories hours
# 1917             5       None       None  None
# 3324             7       None       None  None
# 13023            5       None       None  None

# %%
filtered_df = filtered_df.replace('None', np.nan)  # Replace "None" in specific columns (optional)

# %%
filtered_df = filtered_df.dropna(axis=0)  # Drop rows with any "None" value (all columns)

# %%
funciones.verificar_datos(filtered_df)
# Out:
#          columna          tipo_dato  datos_nulos  porcentaje_nulos  \
# 0    business_id    [<class 'str'>]            0               0.0
# 1           name    [<class 'str'>]            0               0.0
# 2        address    [<class 'str'>]            0               0.0
# 3           city    [<class 'str'>]            0               0.0
# 4          state    [<class 'str'>]            0               0.0
# 5       latitude  [<class 'float'>]            0               0.0
# 6      longitude  [<class 'float'>]            0               0.0
# 7          stars  [<class 'float'>]            0               0.0
# 8   review_count    [<class 'int'>]            0               0.0
# 9     attributes   [<class 'dict'>]            0               0.0
# 10    categories    [<class 'str'>]            0               0.0
# 11         hours   [<class 'dict'>]            0               0.0
#
#     porcentaje_no_nulos
# 0                 100.0
# 1                 100.0
# ...

# %%
filtered_df.to_csv('../DATASETS/business_corregido.csv')
