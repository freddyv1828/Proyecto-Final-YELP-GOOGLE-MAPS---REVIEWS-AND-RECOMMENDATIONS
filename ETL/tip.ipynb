# %%
import pandas as pd
import funciones
import numpy as np

# %%
ruta_tip = '../DATASETS/tip_clean.csv'
ruta_business = '../DATASETS/business_corregido.csv'

# %%
# Open file
df_tip = pd.read_csv(ruta_tip)
df_tip.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# 3  OttfcRxgRrYsTg9EV5Aozg  clwjLY7PdYJpe7IP9lrqEw
# 4  j2sEA3hiUcwHfq9Ml6M47g  EXYbKA1tocvOK_1tXxZXLA
#
#                                                 text                 date  \
# 0                     Avengers time with the ladies.  2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban...  2013-02-05 18:35:10
# 2             Appetizers.. platter special for lunch  2012-10-06 19:43:09
# 3                            Order the Tortilla Soup  2014-06-17 01:20:14
# 4  Don't go for dinner. They close at 6. Really Y...  2011-10-13 03:15:15
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# Open file
df_business = pd.read_csv(ruta_business)
df_business.head()
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 2          13  jaxMSoInw8Poo3XeMJt8lQ              Adams Dental
# 3          14  0bPLkL0QhhPO5kt1_EXmNQ      Zio's Italian Market
# 4          16  rBmpy_Y1UbBx8ggHlyb7hA  Arizona Truck Outfitters
#
#                            address           city state  latitude  longitude  \
# 0  87 Grasso Plaza Shopping Center    Los Angeles    CA   34.1141  -118.4068
# 1                      935 Race St          Miami    FL   25.7840   -80.2101
# 2                15 N Missouri Ave  San Francisco    CA   37.7558  -122.4449
# 3                    2575 E Bay Dr      San Diego    CA   32.8313  -117.1222
# 4                  625 N Stone Ave          Tampa    FL   27.9945   -82.4447
#
#    stars  review_count                                         attributes  \
# ...

# %% [markdown]
# Filtramos la informacion del segmento seleccionado para el alcance del proyecto

# %%
df_bisness_id = df_business["business_id"].tolist()

# %%
df_tip_filtered = df_tip[df_tip["business_id"].isin(df_bisness_id)]
df_tip_filtered
# Out:
#                        user_id             business_id  \
# 202     o5ch055ATjfHgNFwgXbGcA  4RMHlggaIdNibPUJPVEd6w
# 253     j7wiNAppjn1HEEqyP8OkqA  GlYN-RJyL_YwxIqsSDo1ag
# 272     jW1DJKo4DH9GsEYKFUHz3w  O_KX1Z4ZXMv0OVvQ9e8pNQ
# 375     CzV4FlITtTjnq8dyiXiGkQ  boLOUdV5T1O5a1cWaClfDA
# 428     I-wq3PJNBlaZ8tpi0SdS8A  frsWe9bmMOMIBOBNzsCTew
# ...                        ...                     ...
# 237308  dFp2aBynPKO_HREEaMNWxQ  rBE5TT_ndOOczNBrbRnJwA
# 237449  WiLMLVHPojfXYsPymL4XLw  cB5NEUkJOSIrjZR-agSltA
# 237748  33uY4ogdZl96ZPds-TuuYw  S2Ho8yLxhKAa26pBAm6rxA
# 237864  PIduS8bX7GEUsJ_uuI0hsg  2g1ZiT6cM1NC4nJ8xS6EGg
# 238044  2dILt0X5cpNb8reAxVXMyA  VEsb_ByMJkuCEDURgfLBDg
#
#                                                      text  \
# 202                                  Great watering hole!
# 253     Poblano potato ham cakes are the special this ...
# 272                                         Great flavors
# 375                                        WAY too salty!
# ...

# %%
funciones.verificar_datos(df_tip_filtered)
# Out:
#             columna        tipo_dato  datos_nulos  porcentaje_nulos  \
# 0           user_id  [<class 'str'>]            0               0.0
# 1       business_id  [<class 'str'>]            0               0.0
# 2              text  [<class 'str'>]            0               0.0
# 3              date  [<class 'str'>]            0               0.0
# 4  compliment_count  [<class 'int'>]            0               0.0
#
#    porcentaje_no_nulos
# 0                100.0
# 1                100.0
# 2                100.0
# 3                100.0
# 4                100.0

# %%
df_tip_filtered.to_csv('../DATASETS/tip_filtered.csv')
