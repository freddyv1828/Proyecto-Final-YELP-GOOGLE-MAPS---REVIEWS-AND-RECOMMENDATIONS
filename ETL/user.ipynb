# %%
import pandas as pd
import funciones
import numpy as np

# %%
ruta_user = '../DATASETS/user_clean.csv'

# %%
ruta_review = '../DATASETS/review_filtered.csv'

# %%
# open
df_user = pd.read_csv(ruta_user)
df_user.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1364\3642535848.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_user = pd.read_csv(ruta_user)
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# ...

# %%
df_reviews = pd.read_csv(ruta_review)
df_reviews.head()
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0           5  z0osLHDvXvzfm57D4DmD2Q  xVKE_HJ2pwUtTdLbL3pnCg
# 1          24  tXHWJWnTdrraHGUqaPWj3g  zKAHSNzqvwsyoFCw3QpafA
# 2          28  PPgbLBvi34A6m7bKJfTwhw  3TL6HZ1JrKcNTvGDWKlrow
# 3          57  dQ3EU6cevDqHAr_ygy1O8A  CNyXcn0c0V5CFmigqqw-Xg
# 4          71  22n_UbOS_iqKKR3IrYhNGw  N1gb_Cx98QrcfA4CPrkY2w
#
#               business_id  stars  useful  \
# 0  S2Ho8yLxhKAa26pBAm6rxA      3       0
# 1  S2Ho8yLxhKAa26pBAm6rxA      4       0
# 2  GyC36Pn0Q1-qHnqXys6yFg      1       0
# 3  oY5LFo6Yxxf32ePna6mEUQ      5       1
# 4  QkyEr9j7il9lJqseTbPe5w      1       1
#
#                                                 text                 date
# 0  Service was crappy, and food was mediocre.  I ...  2016-11-22 00:22:53
# 1  Enjoyed my fish out at a sidewalk table.  A bi...  2018-05-19 01:14:05
# 2  Service and management terrible... After messi...  2013-12-07 13:17:13
# ...

# %%
user_id_reviews = df_reviews["user_id"].tolist()

# %% [markdown]
# Filtramos dataset para obtener solo los usuarios del segemento seleccionado

# %%
df_user_filtered = df_user[df_user["user_id"].isin(user_id_reviews)]

# %%
df_user_filtered = df_user_filtered.drop(columns=["elite", "friends"])

# %%
df_user_filtered.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'fans', 'average_stars', 'compliment_hot', 'compliment_more',
#        'compliment_profile', 'compliment_cute', 'compliment_list',
#        'compliment_note', 'compliment_plain', 'compliment_cool',
#        'compliment_funny', 'compliment_writer', 'compliment_photos'],
#       dtype='object')

# %% [markdown]
# Marcamos como sin nombre los registros nulos de los nombres de los usuarios ya que solo tienen como nulo los nombres y el resto de la nformacion es valiosa

# %%
# Suponiendo que quieres reemplazar los nulos con "Sin nombre"
df_user_filtered['name'].fillna('Sin nombre', inplace=True)

# %%
funciones.verificar_datos(df_user_filtered)
# Out:
#                columna          tipo_dato  datos_nulos  porcentaje_nulos  \
# 0              user_id    [<class 'str'>]            0               0.0
# 1                 name    [<class 'str'>]            0               0.0
# 2         review_count    [<class 'int'>]            0               0.0
# 3        yelping_since    [<class 'str'>]            0               0.0
# 4               useful    [<class 'int'>]            0               0.0
# 5                funny    [<class 'int'>]            0               0.0
# 6                 cool    [<class 'int'>]            0               0.0
# 7                 fans    [<class 'int'>]            0               0.0
# 8        average_stars  [<class 'float'>]            0               0.0
# 9       compliment_hot    [<class 'int'>]            0               0.0
# 10     compliment_more    [<class 'int'>]            0               0.0
# 11  compliment_profile    [<class 'int'>]            0               0.0
# ...

# %%
df_user_filtered.to_csv('../DATASETS/user_filtered.csv')
